# %%
from langchain_core.tools import tool
from typing import TypedDict
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
from pydantic import Field, BaseModel

# %%
x = load_dotenv()
# Out:
# True

# %%
class Fun(TypedDict):
    num: float = Field(description="A random Number generated by user")
    chat_guess: float = Field(description='Guess of the LLM')
    is_greater: bool = Field(description='Flag for greater and less')

# %%
graph = StateGraph(Fun)

# %%
@tool 
def llm_guess(state: Fun) -> dict:
    pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 @tool
#       2 def llm_guess(state: Fun) -> dict:
#       3     pass
#
# File f:\Summer 26\Langchain and LangGraph\Myenv\Lib\site-packages\langchain_core\tools\convert.py:364, in tool(name_or_callable, runnable, description, return_direct, args_schema, infer_schema, response_format, parse_docstring, error_on_invalid_docstring, extras, *args)
#     358 if name_or_callable is not None:
#     359     if callable(name_or_callable) and hasattr(name_or_callable, "__name__"):
#     360         # Used as a decorator without parameters
#     361         # @tool
#     362         # def my_tool():
#     363         #    pass
# --> 364         return _create_tool_factory(name_or_callable.__name__)(name_or_callable)
#     365     if isinstance(name_or_callable, str):
#     366         # Used with a new name for the tool
#     367         # @tool("search")
#    (...)    374         # def my_tool():
#     375         #    pass
#     376         return _create_tool_factory(name_or_callable)
#
# File f:\Summer 26\Langchain and LangGraph\Myenv\Lib\site-packages\langchain_core\tools\convert.py:307, in tool.<locals>._create_tool_factory.<locals>._tool_factory(dec_func)
#     304     schema = args_schema
#     306 if infer_schema or args_schema is not None:
# --> 307     return StructuredTool.from_function(
#     308         func,
#     309         coroutine,
#     310         name=tool_name,
#     311         description=tool_description,
#     312         return_direct=return_direct,
#     313         args_schema=schema,
#     314         infer_schema=infer_schema,
#     315         response_format=response_format,
#     316         parse_docstring=parse_docstring,
#     317         error_on_invalid_docstring=error_on_invalid_docstring,
#     318         extras=extras,
#     319     )
#     320 # If someone doesn't want a schema applied, we must treat it as
#     321 # a simple string->string function
#     322 if dec_func.__doc__ is None:
#
# File f:\Summer 26\Langchain and LangGraph\Myenv\Lib\site-packages\langchain_core\tools\structured.py:235, in StructuredTool.from_function(cls, func, coroutine, name, description, return_direct, args_schema, infer_schema, response_format, parse_docstring, error_on_invalid_docstring, **kwargs)
#     233 if description_ is None:
#     234     msg = "Function must have a docstring if description not provided."
# --> 235     raise ValueError(msg)
#     236 if description is None:
#     237     # Only apply if using the function's docstring
#     238     description_ = textwrap.dedent(description_).strip()
#
# ValueError: Function must have a docstring if description not provided.

# %%
graph.add_node('llm_guess', llm_guess)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 graph.add_node(START, 'execute')
#
# File f:\Summer 26\Langchain and LangGraph\Myenv\Lib\site-packages\langgraph\graph\state.py:795, in StateGraph.add_node(self, node, action, defer, metadata, input_schema, retry_policy, cache_policy, error_handler, destinations, timeout, **kwargs)
#     793     raise ValueError(f"Node `{node}` already present.")
#     794 if node == END or node == START:
# --> 795     raise ValueError(f"Node `{node}` is reserved.")
#     797 for character in (NS_SEP, NS_END):
#     798     if character in node:
#
# ValueError: Node `__start__` is reserved.
